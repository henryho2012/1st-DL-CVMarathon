# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0068 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00239, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 0.0018 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00239 to 0.00190, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00190 to 0.00187, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00187 to 0.00182, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00182 to 0.00175, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.9545e-04 - val_loss: 0.0018
#
# Epoch 00006: val_loss did not improve from 0.00175
# Epoch 7/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 8.6929e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00175 to 0.00148, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 7.2719e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00148 to 0.00140, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 6.4316e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00140 to 0.00138, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 5.8389e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00138 to 0.00115, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 467us/step - loss: 5.3219e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00115 to 0.00111, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 4.9074e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00111 to 0.00106, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 4.5247e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00106 to 0.00104, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 4.1920e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00104 to 0.00100, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 4.0428e-04 - val_loss: 9.4693e-04
#
# Epoch 00015: val_loss improved from 0.00100 to 0.00095, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 3.8002e-04 - val_loss: 9.4777e-04
#
# Epoch 00016: val_loss did not improve from 0.00095
# Epoch 17/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 3.6937e-04 - val_loss: 9.1831e-04
#
# Epoch 00017: val_loss improved from 0.00095 to 0.00092, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 3.5063e-04 - val_loss: 9.4089e-04
#
# Epoch 00018: val_loss did not improve from 0.00092
# Epoch 19/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 3.3783e-04 - val_loss: 9.2250e-04
#
# Epoch 00019: val_loss did not improve from 0.00092
# Epoch 20/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 3.2975e-04 - val_loss: 9.2734e-04
#
# Epoch 00020: val_loss did not improve from 0.00092
# Epoch 21/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 3.2678e-04 - val_loss: 9.4102e-04
#
# Epoch 00021: val_loss did not improve from 0.00092
# Epoch 22/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 3.2602e-04 - val_loss: 8.9365e-04
#
# Epoch 00022: val_loss improved from 0.00092 to 0.00089, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.9771e-04 - val_loss: 8.7956e-04
#
# Epoch 00023: val_loss improved from 0.00089 to 0.00088, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 2.9683e-04 - val_loss: 8.5346e-04
#
# Epoch 00024: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.8806e-04 - val_loss: 8.4710e-04
#
# Epoch 00025: val_loss improved from 0.00085 to 0.00085, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.7323e-04 - val_loss: 8.5148e-04
#
# Epoch 00026: val_loss did not improve from 0.00085
# Epoch 27/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 2.7029e-04 - val_loss: 8.5169e-04
#
# Epoch 00027: val_loss did not improve from 0.00085
# Epoch 28/150
# 1712/1712 [==============================] - 1s 469us/step - loss: 2.5984e-04 - val_loss: 8.1767e-04
#
# Epoch 00028: val_loss improved from 0.00085 to 0.00082, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 1s 467us/step - loss: 2.6455e-04 - val_loss: 8.3370e-04
#
# Epoch 00029: val_loss did not improve from 0.00082
# Epoch 30/150
# 1712/1712 [==============================] - 1s 468us/step - loss: 2.4951e-04 - val_loss: 8.6157e-04
#
# Epoch 00030: val_loss did not improve from 0.00082
# Epoch 31/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 2.5113e-04 - val_loss: 8.2131e-04
#
# Epoch 00031: val_loss did not improve from 0.00082
# Epoch 32/150
# 1712/1712 [==============================] - 1s 466us/step - loss: 2.4836e-04 - val_loss: 8.2908e-04
#
# Epoch 00032: val_loss did not improve from 0.00082
# Epoch 33/150
# 1712/1712 [==============================] - 1s 466us/step - loss: 2.4488e-04 - val_loss: 8.1852e-04
#
# Epoch 00033: val_loss did not improve from 0.00082
# Epoch 34/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 2.4148e-04 - val_loss: 8.1268e-04
#
# Epoch 00034: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.2877e-04 - val_loss: 8.5733e-04
#
# Epoch 00035: val_loss did not improve from 0.00081
# Epoch 36/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 2.3308e-04 - val_loss: 8.0764e-04
#
# Epoch 00036: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.2033e-04 - val_loss: 8.1658e-04
#
# Epoch 00037: val_loss did not improve from 0.00081
# Epoch 38/150
# 1712/1712 [==============================] - 1s 466us/step - loss: 2.1793e-04 - val_loss: 8.0704e-04
#
# Epoch 00038: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 2.1598e-04 - val_loss: 8.3296e-04
#
# Epoch 00039: val_loss did not improve from 0.00081
# Epoch 40/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 2.1359e-04 - val_loss: 8.3448e-04
#
# Epoch 00040: val_loss did not improve from 0.00081
# Epoch 41/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 2.0787e-04 - val_loss: 8.0379e-04
#
# Epoch 00041: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.0434e-04 - val_loss: 8.0692e-04
#
# Epoch 00042: val_loss did not improve from 0.00080
# Epoch 43/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 2.0553e-04 - val_loss: 7.9377e-04
# Epoch 00043: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.0076e-04 - val_loss: 8.1564e-04
#
# Epoch 00044: val_loss did not improve from 0.00079
# Epoch 45/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.9867e-04 - val_loss: 8.3349e-04
#
# Epoch 00045: val_loss did not improve from 0.00079
# Epoch 46/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.9421e-04 - val_loss: 8.0288e-04
#
# Epoch 00046: val_loss did not improve from 0.00079
# Epoch 47/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.9337e-04 - val_loss: 8.1030e-04
#
# Epoch 00047: val_loss did not improve from 0.00079
# Epoch 48/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.9403e-04 - val_loss: 7.9864e-04
#
# Epoch 00048: val_loss did not improve from 0.00079
# Epoch 49/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.8954e-04 - val_loss: 8.0465e-04
#
# Epoch 00049: val_loss did not improve from 0.00079
# Epoch 50/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.8658e-04 - val_loss: 7.6429e-04
#
# Epoch 00050: val_loss improved from 0.00079 to 0.00076, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.9303e-04 - val_loss: 7.9198e-04
#
# Epoch 00051: val_loss did not improve from 0.00076
# Epoch 52/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.8590e-04 - val_loss: 8.0368e-04
#
# Epoch 00052: val_loss did not improve from 0.00076
# Epoch 53/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.7645e-04 - val_loss: 8.0722e-04
#
# Epoch 00053: val_loss did not improve from 0.00076
# Epoch 54/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.7349e-04 - val_loss: 8.1500e-04
#
# Epoch 00054: val_loss did not improve from 0.00076
# Epoch 55/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.6924e-04 - val_loss: 7.6899e-04
#
# Epoch 00055: val_loss did not improve from 0.00076
# Epoch 56/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.7205e-04 - val_loss: 8.1920e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.7167e-04 - val_loss: 7.8879e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.6901e-04 - val_loss: 7.8619e-04
#
# Epoch 00058: val_loss did not improve from 0.00076
# Epoch 59/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.6060e-04 - val_loss: 7.8967e-04
#
# Epoch 00059: val_loss did not improve from 0.00076
# Epoch 60/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.6225e-04 - val_loss: 7.9133e-04
#
# Epoch 00060: val_loss did not improve from 0.00076
# Epoch 61/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.6055e-04 - val_loss: 7.8830e-04
#
# Epoch 00061: val_loss did not improve from 0.00076
# Epoch 62/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.6796e-04 - val_loss: 7.7819e-04
#
# Epoch 00062: val_loss did not improve from 0.00076
# Epoch 63/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.6206e-04 - val_loss: 8.0707e-04
#
# Epoch 00063: val_loss did not improve from 0.00076
# Epoch 64/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.5770e-04 - val_loss: 8.3248e-04
#
# Epoch 00064: val_loss did not improve from 0.00076
# Epoch 65/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.5545e-04 - val_loss: 8.5735e-04
#
# Epoch 00065: val_loss did not improve from 0.00076
# Epoch 66/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.5742e-04 - val_loss: 8.4464e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.5461e-04 - val_loss: 8.5393e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.5355e-04 - val_loss: 7.7838e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.4674e-04 - val_loss: 8.2807e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.4914e-04 - val_loss: 8.4767e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.5376e-04 - val_loss: 7.8342e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.4534e-04 - val_loss: 8.4140e-04
#
# Epoch 00072: val_loss did not improve from 0.00076
# Epoch 73/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.4305e-04 - val_loss: 7.9124e-04
#
# Epoch 00073: val_loss did not improve from 0.00076
# Epoch 74/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.4773e-04 - val_loss: 7.8817e-04
#
# Epoch 00074: val_loss did not improve from 0.00076
# Epoch 75/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.4932e-04 - val_loss: 7.8634e-04
#
# Epoch 00075: val_loss did not improve from 0.00076
# Epoch 76/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.4478e-04 - val_loss: 8.1933e-04
#
# Epoch 00076: val_loss did not improve from 0.00076
# Epoch 77/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.4044e-04 - val_loss: 8.0862e-04
#
# Epoch 00077: val_loss did not improve from 0.00076
# Epoch 78/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.3721e-04 - val_loss: 7.9326e-04
#
# Epoch 00078: val_loss did not improve from 0.00076
# Epoch 79/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3731e-04 - val_loss: 7.7139e-04
#
# Epoch 00079: val_loss did not improve from 0.00076
# Epoch 80/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.3723e-04 - val_loss: 8.1172e-04
#
# Epoch 00080: val_loss did not improve from 0.00076
# Epoch 81/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.3453e-04 - val_loss: 7.6679e-04
#
# Epoch 00081: val_loss did not improve from 0.00076
# Epoch 82/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3464e-04 - val_loss: 7.8976e-04
#
# Epoch 00082: val_loss did not improve from 0.00076
# Epoch 83/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3047e-04 - val_loss: 7.8441e-04
#
# Epoch 00083: val_loss did not improve from 0.00076
# Epoch 84/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.3123e-04 - val_loss: 7.9387e-04
#
# Epoch 00084: val_loss did not improve from 0.00076
# Epoch 85/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.2887e-04 - val_loss: 8.0002e-04
#
# Epoch 00085: val_loss did not improve from 0.00076
# Epoch 86/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.3228e-04 - val_loss: 7.8745e-04
#
# Epoch 00086: val_loss did not improve from 0.00076
# Epoch 87/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.2932e-04 - val_loss: 8.0535e-04
#
# Epoch 00087: val_loss did not improve from 0.00076
# Epoch 88/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.2966e-04 - val_loss: 7.9844e-04
#
# Epoch 00088: val_loss did not improve from 0.00076
# Epoch 89/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3084e-04 - val_loss: 7.7505e-04
#
# Epoch 00089: val_loss did not improve from 0.00076
# Epoch 90/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2644e-04 - val_loss: 7.9755e-04
#
# Epoch 00090: val_loss did not improve from 0.00076
# Epoch 91/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.2532e-04 - val_loss: 7.7566e-04
#
# Epoch 00091: val_loss did not improve from 0.00076
# Epoch 92/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.2318e-04 - val_loss: 7.9150e-04
# Epoch 00092: val_loss did not improve from 0.00076
# Epoch 93/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2302e-04 - val_loss: 8.1206e-04
#
# Epoch 00093: val_loss did not improve from 0.00076
# Epoch 94/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.2716e-04 - val_loss: 8.2405e-04
#
# Epoch 00094: val_loss did not improve from 0.00076
# Epoch 95/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1995e-04 - val_loss: 7.8352e-04
#
# Epoch 00095: val_loss did not improve from 0.00076
# Epoch 96/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.1637e-04 - val_loss: 7.7558e-04
#
# Epoch 00096: val_loss did not improve from 0.00076
# Epoch 97/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1681e-04 - val_loss: 7.7668e-04
#
# Epoch 00097: val_loss did not improve from 0.00076
# Epoch 98/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1779e-04 - val_loss: 7.9805e-04
#
# Epoch 00098: val_loss did not improve from 0.00076
# Epoch 99/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1610e-04 - val_loss: 8.0385e-04
#
# Epoch 00099: val_loss did not improve from 0.00076
# Epoch 100/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.1339e-04 - val_loss: 7.8318e-04
#
# Epoch 00100: val_loss did not improve from 0.00076
# Epoch 101/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.1343e-04 - val_loss: 7.9408e-04
#
# Epoch 00101: val_loss did not improve from 0.00076
# Epoch 102/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.1216e-04 - val_loss: 7.8251e-04
#
# Epoch 00102: val_loss did not improve from 0.00076
# Epoch 103/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.1366e-04 - val_loss: 7.9534e-04
#
# Epoch 00103: val_loss did not improve from 0.00076
# Epoch 104/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.1439e-04 - val_loss: 7.7849e-04
#
# Epoch 00104: val_loss did not improve from 0.00076
# Epoch 105/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 1.1601e-04 - val_loss: 7.8074e-04
#
# Epoch 00105: val_loss did not improve from 0.00076
# Epoch 106/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.1572e-04 - val_loss: 7.8148e-04
#
# Epoch 00106: val_loss did not improve from 0.00076
# Epoch 107/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.1033e-04 - val_loss: 7.9699e-04
#
# Epoch 00107: val_loss did not improve from 0.00076
# Epoch 108/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.0801e-04 - val_loss: 8.0422e-04
#
# Epoch 00108: val_loss did not improve from 0.00076
# Epoch 109/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.1124e-04 - val_loss: 7.9436e-04
#
# Epoch 00109: val_loss did not improve from 0.00076
# Epoch 110/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.0717e-04 - val_loss: 7.8964e-04
#
# Epoch 00110: val_loss did not improve from 0.00076
# Epoch 111/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.0793e-04 - val_loss: 7.8074e-04
#
# Epoch 00111: val_loss did not improve from 0.00076
# Epoch 112/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.0898e-04 - val_loss: 7.9075e-04
#
# Epoch 00112: val_loss did not improve from 0.00076
# Epoch 113/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.0756e-04 - val_loss: 7.9410e-04
#
# Epoch 00113: val_loss did not improve from 0.00076
# Epoch 114/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.0359e-04 - val_loss: 7.8999e-04
#
# Epoch 00114: val_loss did not improve from 0.00076
# Epoch 115/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.0406e-04 - val_loss: 8.0372e-04
#
# Epoch 00115: val_loss did not improve from 0.00076
# Epoch 116/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.0461e-04 - val_loss: 8.4882e-04
#
# Epoch 00116: val_loss did not improve from 0.00076
# Epoch 117/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.0836e-04 - val_loss: 8.3918e-04
#
# Epoch 00117: val_loss did not improve from 0.00076
# Epoch 118/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.1211e-04 - val_loss: 8.5715e-04
#
# Epoch 00118: val_loss did not improve from 0.00076
# Epoch 119/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.0695e-04 - val_loss: 7.8059e-04
#
# Epoch 00119: val_loss did not improve from 0.00076
# Epoch 120/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.0245e-04 - val_loss: 7.6000e-04
#
# Epoch 00120: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 121/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.0011e-04 - val_loss: 7.7274e-04
#
# Epoch 00121: val_loss did not improve from 0.00076
# Epoch 122/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 9.9734e-05 - val_loss: 7.6062e-04
#
# Epoch 00122: val_loss did not improve from 0.00076
# Epoch 123/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.0115e-04 - val_loss: 8.2912e-04
#
# Epoch 00123: val_loss did not improve from 0.00076
# Epoch 124/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.0528e-04 - val_loss: 7.9045e-04
#
# Epoch 00124: val_loss did not improve from 0.00076
# Epoch 125/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.9841e-05 - val_loss: 7.9804e-04
#
# Epoch 00125: val_loss did not improve from 0.00076
# Epoch 126/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 9.7549e-05 - val_loss: 7.7166e-04
#
# Epoch 00126: val_loss did not improve from 0.00076
# Epoch 127/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 9.6047e-05 - val_loss: 8.0803e-04
#
# Epoch 00127: val_loss did not improve from 0.00076
# Epoch 128/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.1547e-05 - val_loss: 8.2012e-04
#
# Epoch 00128: val_loss did not improve from 0.00076
# Epoch 129/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.0099e-04 - val_loss: 8.3215e-04
#
# Epoch 00129: val_loss did not improve from 0.00076
# Epoch 130/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 9.9624e-05 - val_loss: 7.7493e-04
#
# Epoch 00130: val_loss did not improve from 0.00076
# Epoch 131/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 9.7903e-05 - val_loss: 7.6670e-04
#
# Epoch 00131: val_loss did not improve from 0.00076
# Epoch 132/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.6857e-05 - val_loss: 7.7723e-04
#
# Epoch 00132: val_loss did not improve from 0.00076
# Epoch 133/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.5872e-05 - val_loss: 7.9942e-04
#
# Epoch 00133: val_loss did not improve from 0.00076
# Epoch 134/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.2723e-05 - val_loss: 8.1383e-04
#
# Epoch 00134: val_loss did not improve from 0.00076
# Epoch 135/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.1258e-05 - val_loss: 7.7540e-04
#
# Epoch 00135: val_loss did not improve from 0.00076
# Epoch 136/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.2593e-05 - val_loss: 7.9081e-04
#
# Epoch 00136: val_loss did not improve from 0.00076
# Epoch 137/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 8.8795e-05 - val_loss: 8.1011e-04
#
# Epoch 00137: val_loss did not improve from 0.00076
# Epoch 138/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.1172e-05 - val_loss: 7.8725e-04
#
# Epoch 00138: val_loss did not improve from 0.00076
# Epoch 139/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 9.1789e-05 - val_loss: 8.1286e-04
#
# Epoch 00139: val_loss did not improve from 0.00076
# Epoch 140/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.4403e-05 - val_loss: 7.9606e-04
#
# Epoch 00140: val_loss did not improve from 0.00076
# Epoch 141/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 9.1599e-05 - val_loss: 8.0145e-04
# Epoch 00141: val_loss did not improve from 0.00076
# Epoch 142/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 8.8898e-05 - val_loss: 7.9129e-04
#
# Epoch 00142: val_loss did not improve from 0.00076
# Epoch 143/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 8.9886e-05 - val_loss: 7.8982e-04
#
# Epoch 00143: val_loss did not improve from 0.00076
# Epoch 144/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 8.7713e-05 - val_loss: 8.1279e-04
#
# Epoch 00144: val_loss did not improve from 0.00076
# Epoch 145/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 8.7281e-05 - val_loss: 8.0855e-04
#
# Epoch 00145: val_loss did not improve from 0.00076
# Epoch 146/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 8.8020e-05 - val_loss: 8.0373e-04
#
# Epoch 00146: val_loss did not improve from 0.00076
# Epoch 147/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 8.8659e-05 - val_loss: 8.0275e-04
#
# Epoch 00147: val_loss did not improve from 0.00076
# Epoch 148/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 8.6734e-05 - val_loss: 7.9116e-04
#
# Epoch 00148: val_loss did not improve from 0.00076
# Epoch 149/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 8.7855e-05 - val_loss: 7.9764e-04
#
# Epoch 00149: val_loss did not improve from 0.00076
# Epoch 150/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 8.6640e-05 - val_loss: 7.9554e-04
#
# Epoch 00150: val_loss did not improve from 0.00076

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 2s 668us/step - loss: 0.0044 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00194, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 2s 476us/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00002: val_loss improved from 0.00194 to 0.00180, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00003: val_loss improved from 0.00180 to 0.00168, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 7.9147e-04 - val_loss: 0.0014
#
# Epoch 00004: val_loss improved from 0.00168 to 0.00138, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 6.2718e-04 - val_loss: 0.0011
#
# Epoch 00005: val_loss improved from 0.00138 to 0.00114, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 5.3875e-04 - val_loss: 9.9387e-04
#
# Epoch 00006: val_loss improved from 0.00114 to 0.00099, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 4.6434e-04 - val_loss: 9.0411e-04
#
# Epoch 00007: val_loss improved from 0.00099 to 0.00090, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 4.1613e-04 - val_loss: 8.5118e-04
#
# Epoch 00008: val_loss improved from 0.00090 to 0.00085, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 3.8167e-04 - val_loss: 8.4245e-04
#
# Epoch 00009: val_loss improved from 0.00085 to 0.00084, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 3.5887e-04 - val_loss: 8.4273e-04
#
# Epoch 00010: val_loss did not improve from 0.00084
# Epoch 11/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 3.3616e-04 - val_loss: 7.5803e-04
#
# Epoch 00011: val_loss improved from 0.00084 to 0.00076, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 3.1730e-04 - val_loss: 7.3185e-04
#
# Epoch 00012: val_loss improved from 0.00076 to 0.00073, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 3.0085e-04 - val_loss: 7.1897e-04
#
# Epoch 00013: val_loss improved from 0.00073 to 0.00072, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 2.8916e-04 - val_loss: 7.2494e-04
#
# Epoch 00014: val_loss did not improve from 0.00072
# Epoch 15/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 2.7544e-04 - val_loss: 7.0390e-04
#
# Epoch 00015: val_loss improved from 0.00072 to 0.00070, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 2.7822e-04 - val_loss: 6.9787e-04
#
# Epoch 00016: val_loss improved from 0.00070 to 0.00070, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 2s 475us/step - loss: 2.5144e-04 - val_loss: 7.2456e-04
#
# Epoch 00017: val_loss did not improve from 0.00070
# Epoch 18/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 2.4932e-04 - val_loss: 7.1336e-04
#
# Epoch 00018: val_loss did not improve from 0.00070
# Epoch 19/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 2.3814e-04 - val_loss: 7.0057e-04
#
# Epoch 00019: val_loss did not improve from 0.00070
# Epoch 20/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 2.2953e-04 - val_loss: 6.7977e-04
#
# Epoch 00020: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 2.2835e-04 - val_loss: 6.8591e-04
#
# Epoch 00021: val_loss did not improve from 0.00068
# Epoch 22/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 2.1560e-04 - val_loss: 6.6123e-04
#
# Epoch 00022: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 2.1677e-04 - val_loss: 7.1118e-04
#
# Epoch 00023: val_loss did not improve from 0.00066
# Epoch 24/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 2.0348e-04 - val_loss: 6.8218e-04
#
# Epoch 00024: val_loss did not improve from 0.00066
# Epoch 25/150
# 3424/3424 [==============================] - 2s 473us/step - loss: 2.0088e-04 - val_loss: 6.4973e-04
#
# Epoch 00025: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 26/150
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.9594e-04 - val_loss: 6.4496e-04
#
# Epoch 00026: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 27/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.9485e-04 - val_loss: 6.4421e-04
#
# Epoch 00027: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 2s 472us/step - loss: 1.9159e-04 - val_loss: 6.8454e-04
#
# Epoch 00028: val_loss did not improve from 0.00064
# Epoch 29/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 1.8775e-04 - val_loss: 6.7379e-04
#
# Epoch 00029: val_loss did not improve from 0.00064
# Epoch 30/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.8247e-04 - val_loss: 6.5314e-04
#
# Epoch 00030: val_loss did not improve from 0.00064
# Epoch 31/150
# 3424/3424 [==============================] - 2s 473us/step - loss: 1.7728e-04 - val_loss: 6.6283e-04
#
# Epoch 00031: val_loss did not improve from 0.00064
# Epoch 32/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.8005e-04 - val_loss: 6.2870e-04
#
# Epoch 00032: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 1.7236e-04 - val_loss: 6.6412e-04
#
# Epoch 00033: val_loss did not improve from 0.00063
# Epoch 34/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.7123e-04 - val_loss: 6.8188e-04
#
# Epoch 00034: val_loss did not improve from 0.00063
# Epoch 35/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.6625e-04 - val_loss: 6.4520e-04
#
# Epoch 00035: val_loss did not improve from 0.00063
# Epoch 36/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.6083e-04 - val_loss: 6.5961e-04
#
# Epoch 00036: val_loss did not improve from 0.00063
# Epoch 37/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.5970e-04 - val_loss: 6.6952e-04
#
# Epoch 00037: val_loss did not improve from 0.00063
# Epoch 38/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.5765e-04 - val_loss: 6.7996e-04
#
# Epoch 00038: val_loss did not improve from 0.00063
# Epoch 39/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.5405e-04 - val_loss: 6.3701e-04
#
# Epoch 00039: val_loss did not improve from 0.00063
# Epoch 40/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 1.5640e-04 - val_loss: 6.6529e-04
#
# Epoch 00040: val_loss did not improve from 0.00063
# Epoch 41/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.5148e-04 - val_loss: 6.2755e-04
#
# Epoch 00041: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.5032e-04 - val_loss: 6.2655e-04
#
# Epoch 00042: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 43/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.4901e-04 - val_loss: 6.9912e-04
#
# Epoch 00043: val_loss did not improve from 0.00063
# Epoch 44/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 1.4449e-04 - val_loss: 6.2472e-04
#
# Epoch 00044: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 45/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 1.4063e-04 - val_loss: 6.4976e-04
#
# Epoch 00045: val_loss did not improve from 0.00062
# Epoch 46/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 1.3624e-04 - val_loss: 6.3794e-04
#
# Epoch 00046: val_loss did not improve from 0.00062
# Epoch 47/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 1.3922e-04 - val_loss: 6.8401e-04
#
# Epoch 00047: val_loss did not improve from 0.00062
# Epoch 48/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.3912e-04 - val_loss: 6.3809e-04
#
# Epoch 00048: val_loss did not improve from 0.00062
# Epoch 49/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.3471e-04 - val_loss: 6.6687e-04
#
# Epoch 00049: val_loss did not improve from 0.00062
# Epoch 50/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 1.3132e-04 - val_loss: 6.4998e-04
#
# Epoch 00050: val_loss did not improve from 0.00062
# Epoch 51/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.3089e-04 - val_loss: 6.2744e-04
#
# Epoch 00051: val_loss did not improve from 0.00062
# Epoch 52/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 1.2594e-04 - val_loss: 6.6308e-04
#
# Epoch 00052: val_loss did not improve from 0.00062
# Epoch 53/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 1.2898e-04 - val_loss: 6.4612e-04
#
# Epoch 00053: val_loss did not improve from 0.00062
# Epoch 54/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 1.2841e-04 - val_loss: 6.5610e-04
#
# Epoch 00054: val_loss did not improve from 0.00062
# Epoch 55/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 1.2501e-04 - val_loss: 6.5319e-04
#
# Epoch 00055: val_loss did not improve from 0.00062
# Epoch 56/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.2484e-04 - val_loss: 6.2530e-04
#
# Epoch 00056: val_loss did not improve from 0.00062
# Epoch 57/150
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.2149e-04 - val_loss: 6.6187e-04
#
# Epoch 00057: val_loss did not improve from 0.00062
# Epoch 58/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.1852e-04 - val_loss: 6.2155e-04
#
# Epoch 00058: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 59/150
# 3424/3424 [==============================] - 2s 477us/step - loss: 1.1847e-04 - val_loss: 6.3919e-04
#
# Epoch 00059: val_loss did not improve from 0.00062
# Epoch 60/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 1.1968e-04 - val_loss: 6.4961e-04
#
# Epoch 00060: val_loss did not improve from 0.00062
# Epoch 61/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.1759e-04 - val_loss: 6.4852e-04
#
# Epoch 00061: val_loss did not improve from 0.00062
# Epoch 62/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.1611e-04 - val_loss: 6.7504e-04
#
# Epoch 00062: val_loss did not improve from 0.00062
# Epoch 63/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 1.1318e-04 - val_loss: 6.7205e-04
#
# Epoch 00063: val_loss did not improve from 0.00062
# Epoch 64/150
# 3424/3424 [==============================] - 2s 473us/step - loss: 1.1185e-04 - val_loss: 6.3409e-04
#
# Epoch 00064: val_loss did not improve from 0.00062
# Epoch 65/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 1.1104e-04 - val_loss: 6.2834e-04
#
# Epoch 00065: val_loss did not improve from 0.00062
# Epoch 66/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 1.0867e-04 - val_loss: 6.7073e-04
#
# Epoch 00066: val_loss did not improve from 0.00062
# Epoch 67/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 1.0894e-04 - val_loss: 6.4294e-04
#
# Epoch 00067: val_loss did not improve from 0.00062
# Epoch 68/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.0841e-04 - val_loss: 6.5795e-04
#
# Epoch 00068: val_loss did not improve from 0.00062
# Epoch 69/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 1.0917e-04 - val_loss: 6.7499e-04
#
# Epoch 00069: val_loss did not improve from 0.00062
# Epoch 70/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.0715e-04 - val_loss: 6.4810e-04
#
# Epoch 00070: val_loss did not improve from 0.00062
# Epoch 71/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.0673e-04 - val_loss: 6.5067e-04
#
# Epoch 00071: val_loss did not improve from 0.00062
# Epoch 72/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.0315e-04 - val_loss: 6.4083e-04
#
# Epoch 00072: val_loss did not improve from 0.00062
# Epoch 73/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.0248e-04 - val_loss: 6.2600e-04
#
# Epoch 00073: val_loss did not improve from 0.00062
# Epoch 74/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.0168e-04 - val_loss: 6.5357e-04
#
# Epoch 00074: val_loss did not improve from 0.00062
# Epoch 75/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.0157e-04 - val_loss: 6.4583e-04
#
# Epoch 00075: val_loss did not improve from 0.00062
# Epoch 76/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 1.0106e-04 - val_loss: 6.4531e-04
#
# Epoch 00076: val_loss did not improve from 0.00062
# Epoch 77/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 9.9093e-05 - val_loss: 6.5400e-04
#
# Epoch 00077: val_loss did not improve from 0.00062
# Epoch 78/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 1.0199e-04 - val_loss: 6.4883e-04
#
# Epoch 00078: val_loss did not improve from 0.00062
# Epoch 79/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 1.0019e-04 - val_loss: 6.7689e-04
#
# Epoch 00079: val_loss did not improve from 0.00062
# Epoch 80/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 9.7902e-05 - val_loss: 6.7063e-04
#
# Epoch 00080: val_loss did not improve from 0.00062
# Epoch 81/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 9.6348e-05 - val_loss: 6.5199e-04
#
# Epoch 00081: val_loss did not improve from 0.00062
# Epoch 82/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 9.6086e-05 - val_loss: 6.3690e-04
#
# Epoch 00082: val_loss did not improve from 0.00062
# Epoch 83/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 9.5831e-05 - val_loss: 6.4256e-04
#
# Epoch 00083: val_loss did not improve from 0.00062
# Epoch 84/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 9.5075e-05 - val_loss: 6.3872e-04
#
# Epoch 00084: val_loss did not improve from 0.00062
# Epoch 85/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 9.5867e-05 - val_loss: 6.6243e-04
#
# Epoch 00085: val_loss did not improve from 0.00062
# Epoch 86/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 9.5073e-05 - val_loss: 6.5073e-04
#
# Epoch 00086: val_loss did not improve from 0.00062
# Epoch 87/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 9.3127e-05 - val_loss: 6.7395e-04
#
# Epoch 00087: val_loss did not improve from 0.00062
# Epoch 88/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 9.3942e-05 - val_loss: 6.5504e-04
#
# Epoch 00088: val_loss did not improve from 0.00062
# Epoch 89/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.9930e-05 - val_loss: 6.2470e-04
#
# Epoch 00089: val_loss did not improve from 0.00062
# Epoch 90/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 9.0664e-05 - val_loss: 6.5964e-04
#
# Epoch 00090: val_loss did not improve from 0.00062
# Epoch 91/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 9.5817e-05 - val_loss: 6.4444e-04
#
# Epoch 00091: val_loss did not improve from 0.00062
# Epoch 92/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 9.3048e-05 - val_loss: 6.6949e-04
#
# Epoch 00092: val_loss did not improve from 0.00062
# Epoch 93/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 8.8019e-05 - val_loss: 6.2472e-04
#
# Epoch 00093: val_loss did not improve from 0.00062
# Epoch 94/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 9.0646e-05 - val_loss: 6.7185e-04
#
# Epoch 00094: val_loss did not improve from 0.00062
# Epoch 95/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 8.8008e-05 - val_loss: 6.3042e-04
#
# Epoch 00095: val_loss did not improve from 0.00062
# Epoch 96/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.8727e-05 - val_loss: 6.5341e-04
#
# Epoch 00096: val_loss did not improve from 0.00062
# Epoch 97/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 8.9393e-05 - val_loss: 6.1939e-04
#
# Epoch 00097: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 98/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 8.7071e-05 - val_loss: 6.3848e-04
#
# Epoch 00098: val_loss did not improve from 0.00062
# Epoch 99/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.9575e-05 - val_loss: 6.5876e-04
#
# Epoch 00099: val_loss did not improve from 0.00062
# Epoch 100/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.9122e-05 - val_loss: 6.6347e-04
#
# Epoch 00100: val_loss did not improve from 0.00062
# Epoch 101/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.5136e-05 - val_loss: 6.4195e-04
#
# Epoch 00101: val_loss did not improve from 0.00062
# Epoch 102/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.7074e-05 - val_loss: 6.4930e-04
#
# Epoch 00102: val_loss did not improve from 0.00062
# Epoch 103/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.5047e-05 - val_loss: 6.5480e-04
#
# Epoch 00103: val_loss did not improve from 0.00062
# Epoch 104/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 9.4692e-05 - val_loss: 6.2880e-04
#
# Epoch 00104: val_loss did not improve from 0.00062
# Epoch 105/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.6938e-05 - val_loss: 6.7005e-04
#
# Epoch 00105: val_loss did not improve from 0.00062
# Epoch 106/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.4998e-05 - val_loss: 6.6523e-04
#
# Epoch 00106: val_loss did not improve from 0.00062
# Epoch 107/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.4028e-05 - val_loss: 6.6205e-04
#
# Epoch 00107: val_loss did not improve from 0.00062
# Epoch 108/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.4115e-05 - val_loss: 6.4392e-04
#
# Epoch 00108: val_loss did not improve from 0.00062
# Epoch 109/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.3196e-05 - val_loss: 6.4610e-04
#
# Epoch 00109: val_loss did not improve from 0.00062
# Epoch 110/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.3022e-05 - val_loss: 6.6209e-04
#
# Epoch 00110: val_loss did not improve from 0.00062
# Epoch 111/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.5173e-05 - val_loss: 6.4115e-04
#
# Epoch 00111: val_loss did not improve from 0.00062
# Epoch 112/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.0397e-05 - val_loss: 6.4463e-04
#
# Epoch 00112: val_loss did not improve from 0.00062
# Epoch 113/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.2046e-05 - val_loss: 6.4830e-04
#
# Epoch 00113: val_loss did not improve from 0.00062
# Epoch 114/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 8.2654e-05 - val_loss: 6.7039e-04
#
# Epoch 00114: val_loss did not improve from 0.00062
# Epoch 115/150
# 3424/3424 [==============================] - 2s 474us/step - loss: 8.1677e-05 - val_loss: 6.5899e-04
#
# Epoch 00115: val_loss did not improve from 0.00062
# Epoch 116/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 8.2536e-05 - val_loss: 6.4410e-04
#
# Epoch 00116: val_loss did not improve from 0.00062
# Epoch 117/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 8.1835e-05 - val_loss: 6.6541e-04
#
# Epoch 00117: val_loss did not improve from 0.00062
# Epoch 118/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 8.2978e-05 - val_loss: 6.4373e-04
#
# Epoch 00118: val_loss did not improve from 0.00062
# Epoch 119/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.9855e-05 - val_loss: 6.5784e-04
#
# Epoch 00119: val_loss did not improve from 0.00062
# Epoch 120/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 7.9590e-05 - val_loss: 6.8476e-04
#
# Epoch 00120: val_loss did not improve from 0.00062
# Epoch 121/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 8.1566e-05 - val_loss: 6.4977e-04
#
# Epoch 00121: val_loss did not improve from 0.00062
# Epoch 122/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 7.8545e-05 - val_loss: 6.3763e-04
#
# Epoch 00122: val_loss did not improve from 0.00062
# Epoch 123/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.9828e-05 - val_loss: 6.5292e-04
#
# Epoch 00123: val_loss did not improve from 0.00062
# Epoch 124/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.7063e-05 - val_loss: 6.4588e-04
#
# Epoch 00124: val_loss did not improve from 0.00062
# Epoch 125/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 7.6952e-05 - val_loss: 6.2853e-04
#
# Epoch 00125: val_loss did not improve from 0.00062
# Epoch 126/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.7415e-05 - val_loss: 6.3972e-04
#
# Epoch 00126: val_loss did not improve from 0.00062
# Epoch 127/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 7.7388e-05 - val_loss: 6.3811e-04
#
# Epoch 00127: val_loss did not improve from 0.00062
# Epoch 128/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 7.7993e-05 - val_loss: 6.3542e-04
#
# Epoch 00128: val_loss did not improve from 0.00062
# Epoch 129/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 7.9226e-05 - val_loss: 6.5755e-04
#
# Epoch 00129: val_loss did not improve from 0.00062
# Epoch 130/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 7.9005e-05 - val_loss: 6.3220e-04
#
# Epoch 00130: val_loss did not improve from 0.00062
# Epoch 131/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 7.5192e-05 - val_loss: 6.4239e-04
#
# Epoch 00131: val_loss did not improve from 0.00062
# Epoch 132/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.5685e-05 - val_loss: 6.6157e-04
#
# Epoch 00132: val_loss did not improve from 0.00062
# Epoch 133/150
# 3424/3424 [==============================] - 2s 472us/step - loss: 8.1601e-05 - val_loss: 6.3333e-04
#
# Epoch 00133: val_loss did not improve from 0.00062
# Epoch 134/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 7.6099e-05 - val_loss: 6.3024e-04
#
# Epoch 00134: val_loss did not improve from 0.00062
# Epoch 135/150
# 3424/3424 [==============================] - 2s 472us/step - loss: 7.8518e-05 - val_loss: 6.5787e-04
#
# Epoch 00135: val_loss did not improve from 0.00062
# Epoch 136/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 7.7655e-05 - val_loss: 6.5182e-04
#
# Epoch 00136: val_loss did not improve from 0.00062
# Epoch 137/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 7.7123e-05 - val_loss: 6.5728e-04
#
# Epoch 00137: val_loss did not improve from 0.00062
# Epoch 138/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 7.5765e-05 - val_loss: 6.4723e-04
#
# Epoch 00138: val_loss did not improve from 0.00062
# Epoch 139/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.3346e-05 - val_loss: 6.5347e-04
#
# Epoch 00139: val_loss did not improve from 0.00062
# Epoch 140/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 7.5243e-05 - val_loss: 6.3594e-04
#
# Epoch 00140: val_loss did not improve from 0.00062
# Epoch 141/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 7.6678e-05 - val_loss: 6.5253e-04
#
# Epoch 00141: val_loss did not improve from 0.00062
# Epoch 142/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 7.4827e-05 - val_loss: 6.3653e-04
#
# Epoch 00142: val_loss did not improve from 0.00062
# Epoch 143/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 7.7944e-05 - val_loss: 6.4007e-04
#
# Epoch 00143: val_loss did not improve from 0.00062
# Epoch 144/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 7.7100e-05 - val_loss: 6.3851e-04
#
# Epoch 00144: val_loss did not improve from 0.00062
# Epoch 145/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 7.3917e-05 - val_loss: 6.4177e-04
#
# Epoch 00145: val_loss did not improve from 0.00062
# Epoch 146/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 7.4652e-05 - val_loss: 6.5890e-04
#
# Epoch 00146: val_loss did not improve from 0.00062
# Epoch 147/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 7.3749e-05 - val_loss: 6.3826e-04
#
# Epoch 00147: val_loss did not improve from 0.00062
# Epoch 148/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 7.3828e-05 - val_loss: 6.5275e-04
#
# Epoch 00148: val_loss did not improve from 0.00062
# Epoch 149/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.0879e-05 - val_loss: 6.3744e-04
#
# Epoch 00149: val_loss did not improve from 0.00062
# Epoch 150/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 7.4148e-05 - val_loss: 6.4759e-04
#
# Epoch 00150: val_loss did not improve from 0.00062

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
